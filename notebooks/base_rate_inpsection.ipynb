# %% [markdown]
# ### Bank of England Historic Base Rates Data Inspection

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/base_rates_historic.csv')
df.head()
# Out:
#   Date Changed  Rate
# 0    18-Dec-25  3.75
# 1    07-Aug-25  4.00
# 2    08-May-25  4.25
# 3    06-Feb-25  4.50
# 4    07-Nov-24  4.75
